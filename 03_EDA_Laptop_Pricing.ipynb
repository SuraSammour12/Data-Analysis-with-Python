# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the dataset
#
# filepath="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod2.csv"

# %%
df = pd.read_csv('laptop_pricing_dataset_mod2.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0             0           0         Acer         4    2   1         5
# 1             1           1         Dell         3    1   1         3
# 2             2           2         Dell         3    1   1         7
# 3             3           3         Dell         4    2   1         5
# 4             4           4           HP         4    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# 0    978          Low               0                 1
# 1    634          Low               1                 0
# 2    946          Low               1                 0
# 3   1244          Low               0                 1
# 4    837          Low               1                 0

# %% [markdown]
# # Visualize individual feature patterns
#
# Generate regression plots for each of the parameters "CPU_frequency", "Screen_Size_inch" and "Weight_pounds" against "Price". Also, print the value of correlation of each feature with "Price".

# %%
# CPU_frequency plot
sns.regplot(x="CPU_frequency", y="Price", data=df)
plt.show()

# %%
# Screen_Size_inch plot
sns.regplot(x="Screen_Size_inch", y="Price", data=df)
plt.show()

# %%
# Weight_pounds plot
sns.regplot(x='Weight_pounds',y='Price',data=df)
plt.show()

# %% [markdown]
# # Correlation values of the three attributes with Price

# %%
for param in ["CPU_frequency", "Screen_Size_inch","Weight_pounds"]:
    print(f"Correlation of Price and {param} is \n", df[[param,"Price"]].corr())
# Out:
# Correlation of Price and CPU_frequency is
#                 CPU_frequency     Price
# CPU_frequency       1.000000  0.366666
# Price               0.366666  1.000000
# Correlation of Price and Screen_Size_inch is
#                    Screen_Size_inch     Price
# Screen_Size_inch          1.000000 -0.110644
# Price                    -0.110644  1.000000
# Correlation of Price and Weight_pounds is
#                 Weight_pounds     Price
# Weight_pounds       1.000000 -0.050312
# Price              -0.050312  1.000000

# %% [markdown]
# "CPU_frequency" has a 36% positive correlation with the price of the laptops. The other two parameters have weak correlation with price.
#
# ---

# %% [markdown]
# # Categorical features
#
# Generate Box plots for the different feature that hold categorical values. These features would be "Category", "GPU", "OS", "CPU_core", "RAM_GB", "Storage_GB_SSD"

# %%
# Category Box plot
sns.boxplot(x='Category',y='Price',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
# GPU Box plot
sns.boxplot(x='GPU',y='Price',data=df)
# Out:
# <Axes: xlabel='GPU', ylabel='Price'>

# %%
# OS Box plot
sns.boxplot(x='OS',y='Price',data=df)
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %%
# RAM_GB Box plot
sns.boxplot(x='RAM_GB',y='Price',data=df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %%
#CPU_core Box plot
sns.boxplot(x='CPU_core',y='Price',data=df)
# Out:
# <Axes: xlabel='CPU_core', ylabel='Price'>

# %%
# RAM_GB Box plot
sns.boxplot(x='RAM_GB',y='Price',data=df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %%
# Storage_GB_SSD Box plot
sns.boxplot(x='Storage_GB_SSD',y='Price',data=df)
# Out:
# <Axes: xlabel='Storage_GB_SSD', ylabel='Price'>

# %% [markdown]
# ---
#
# #  Descriptive Statistical Analysis
#
# Generate the statistical description of all the features being used in the data set. Include "object" data types as well.

# %%
print(df.describe())
print(df.describe(include=['object']))
# Out:
#        Unnamed: 0.1  Unnamed: 0    Category         GPU          OS  \
# count    238.000000  238.000000  238.000000  238.000000  238.000000
# mean     118.500000  118.500000    3.205882    2.151261    1.058824
# std       68.848868   68.848868    0.776533    0.638282    0.235790
# min        0.000000    0.000000    1.000000    1.000000    1.000000
# 25%       59.250000   59.250000    3.000000    2.000000    1.000000
# 50%      118.500000  118.500000    3.000000    2.000000    1.000000
# 75%      177.750000  177.750000    4.000000    3.000000    1.000000
# max      237.000000  237.000000    5.000000    3.000000    2.000000
#
#          CPU_core  Screen_Size_inch  CPU_frequency      RAM_GB  \
# count  238.000000        238.000000     238.000000  238.000000
# mean     5.630252         14.688655       0.813822    7.882353
# std      1.241787          1.166045       0.141860    2.482603
# min      3.000000         12.000000       0.413793    4.000000
# 25%      5.000000         14.000000       0.689655    8.000000
# 50%      5.000000         15.000000       0.862069    8.000000
# 75%      7.000000         15.600000       0.931034    8.000000
# max      7.000000         17.300000       1.000000   16.000000
#
#        Storage_GB_SSD  Weight_pounds        Price  Screen-Full_HD  \
# count      238.000000     238.000000   238.000000      238.000000
# mean       245.781513       4.106221  1462.344538        0.676471
# std         34.765316       1.078442   574.607699        0.468809
# min        128.000000       1.786050   527.000000        0.000000
# 25%        256.000000       3.246863  1066.500000        0.000000
# 50%        256.000000       4.106221  1333.000000        1.000000
# 75%        256.000000       4.851000  1777.000000        1.000000
# max        256.000000       7.938000  3810.000000        1.000000
#
#        Screen-IPS_panel
# count        238.000000
# mean           0.323529
# std            0.468809
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max            1.000000
#        Manufacturer Price-binned
# count           238          238
# unique           11            3
# top            Dell          Low
# freq             71          160

# %% [markdown]
# ---
# # GroupBy and Pivot Tables
#
# Group the parameters "GPU", "CPU_core" and "Price" to make a pivot table and visualize this connection using the pcolor plot.

# %%
# Create the group
df_group_one = df[['GPU','CPU_core','Price']]

# %%
grouped_test1 = df_group_one.groupby(['GPU','CPU_core'],as_index=False).mean()
print(grouped_test1)
# Out:
#    GPU  CPU_core        Price
# 0    1         3   769.250000
# 1    1         5   998.500000
# 2    1         7  1167.941176
# 3    2         3   785.076923
# 4    2         5  1462.197674
# 5    2         7  1744.621622
# 6    3         3   784.000000
# 7    3         5  1220.680000
# 8    3         7  1945.097561

# %%
# Create the Pivot table
grouped_pivot = grouped_test1.pivot(index='GPU',columns='CPU_core')
print(grouped_pivot)
# Out:
#                Price
# CPU_core           3            5            7
# GPU
# 1         769.250000   998.500000  1167.941176
# 2         785.076923  1462.197674  1744.621622
# 3         784.000000  1220.680000  1945.097561

# %%
# Create the Plot
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

fig.colorbar(im)

# %% [markdown]
# ---
# # Pearson Correlation and p-values

# %%
for param in ['RAM_GB','CPU_frequency','Storage_GB_SSD','Screen_Size_inch','Weight_pounds','CPU_core','OS','GPU','Category']:
  pearson_coef,p_value=stats.pearsonr(df[param],df['Price'])
  print(param)
  print(f'The Pearson Correlation for {param} is {pearson_coef}, with a P-value of P = {p_value}')
# Out:
# RAM_GB
# The Pearson Correlation for RAM_GB is 0.5492972971857841, with a P-value of P = 3.681560628842995e-20
# CPU_frequency
# The Pearson Correlation for CPU_frequency is 0.36666555892588615, with a P-value of P = 5.502463350713232e-09
# Storage_GB_SSD
# The Pearson Correlation for Storage_GB_SSD is 0.24342075521810302, with a P-value of P = 0.00014898923191723927
# Screen_Size_inch
# The Pearson Correlation for Screen_Size_inch is -0.11064420817118273, with a P-value of P = 0.08853397846830661
# Weight_pounds
# The Pearson Correlation for Weight_pounds is -0.05031225837751551, with a P-value of P = 0.4397693853433896
# CPU_core
# The Pearson Correlation for CPU_core is 0.4593977773355115, with a P-value of P = 7.912950127009183e-14
# OS
# The Pearson Correlation for OS is -0.22172980114827384, with a P-value of P = 0.0005696642559246719
# GPU
# The Pearson Correlation for GPU is 0.28829819888814273, with a P-value of P = 6.166949698364344e-06
# Category
# The Pearson Correlation for Category is 0.2862427558126413, with a P-value of P = 7.22569623580658e-06
