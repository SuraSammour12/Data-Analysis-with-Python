# %% [markdown]
# # What is the purpose of data wrangling?
#
# To convert data from an initial format to a format that may be better for analysis.

# %%
import pandas as pd

# %%
df = pd.read_csv('auto.csv')
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = headers
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
import numpy as np

# %%
df.replace('?',np.nan,inplace=True)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %% [markdown]
# ---
#
#
# # Evaluating for Missing Data

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %% [markdown]
# "True" means the value is a missing value while "False" means the value is not a missing value.

# %% [markdown]
# ---
# # Count missing values in each column

# %%
for column in missing_data.columns.values.tolist():
  print(column)
  print(missing_data[column].value_counts())
  print("")
# Out:
# symboling
# symboling
# False    204
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    164
# True      40
# Name: count, dtype: int64
#
# make
# make
# False    204
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    204
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    204
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    202
# True       2
# Name: count, dtype: int64
#
# body-style
# body-style
# False    204
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    204
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    204
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    204
# Name: count, dtype: int64
#
# length
# length
# False    204
# Name: count, dtype: int64
#
# width
# width
# False    204
# Name: count, dtype: int64
#
# height
# height
# False    204
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    204
# ...

# %% [markdown]
# # Deal with missing data
#
# How should i deal with missing data?
#
# Drop data
# * a. Drop the whole row
# * b. Drop the whole column
#
# Replace data
# * a. Replace it by mean
# * b. Replace it by frequency
# * c. Replace it based on other functions

# %% [markdown]
# ---
# | **Method**                    | **When to Use It**                                                                | **Suitable Column Type** |
# | ----------------------------- | --------------------------------------------------------------------------------- | ------------------------ |
# | **Replace by mean**           | When the column is numeric and has few missing values                             | Numeric                  |
# | **Replace by mode/frequency** | When the column is categorical and there's a dominant frequent value              | Categorical              |
# | **Drop the row**              | When the missing value cannot be reasonably replaced, or it's the target variable | Any type                 |
#
#
# ---
#
# `*Replace by mean:*`
#
# "normalized-losses": 41 missing data, replace them with mean
#
# "stroke": 4 missing data, replace them with mean
#
# "bore": 4 missing data, replace them with mean
#
# "horsepower": 2 missing data, replace them with mean
#
# "peak-rpm": 2 missing data, replace them with mean
#
#
# `*Replace by frequency:*`
#
# "num-of-doors": 2 missing data, replace them with "four".
#
# Reason: Since four doors is most frequent, it is most likely to occur
#
# `*Drop the whole row:*`
#
# "price": 4 missing data, simply delete the whole row
#
# Reason: You want to predict price. You cannot use any data entry without price data for prediction; therefore any row now without price data is not useful to you.

# %%
df["num-of-doors"].value_counts()
# Out:
# num-of-doors
# four    114
# two      88
# Name: count, dtype: int64

# %% [markdown]
# 114 + 88 = 202 car has a known number of doors
#
# Percentage of cars that have four doors: 56.4%
#
# Percentage of cars that have two doors: 43.6%
#
#
# ---

# %%
# Calculate the mean value for the "normalized-losses" column
avg_norm_loss = df['normalized-losses'].astype('float').mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %%
# Replace "NaN" with mean value in "normalized-losses" column
df['normalized-losses']=df['normalized-losses'].fillna(avg_norm_loss)

# %%
# Calculate the mean value for the "bore" column
avg_bore = df['bore'].astype('float').mean(axis=0)

# %%
# Replace "NaN" with the mean value in the "bore" column
df['bore']=df['bore'].fillna(avg_bore)

# %%
# Replace NaN in "stroke" column with the mean value
avg_stroke = df['stroke'].astype('float').mean(axis=0)
df['stroke']=df['stroke'].fillna(avg_stroke)

# %%
# Replace "NaN" with the mean value in the "horsepower" column
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
df['horsepower']=df['horsepower'].fillna(avg_horsepower)

# %%
# Replace "NaN" with the mean value in the "peak-rpm" column
avg_peakrpm = df['peak-rpm'].astype('float').mean(axis=0)
df['peak-rpm'] = df['peak-rpm'].fillna(avg_peakrpm)

# %%
# To see which values are present in a particular column, i can use the ".value_counts()" method
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      88
# Name: count, dtype: int64

# %% [markdown]
# i can see that four doors is the most common type.

# %%
# i can also use the ".idxmax()" method to calculate the most common type automatically:
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
#replace the missing 'num-of-doors' values by the most frequent
df["num-of-doors"] = df['num-of-doors'].fillna('four')

# %% [markdown]
# Finally, drop all rows that do not have price data:

# %%
df.dropna(subset=['price'],axis=0,inplace=True)

# %% [markdown]
#  reset index, because we droped two rows

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          1             122.0  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2             122.0         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %% [markdown]
# # Now, i have a data set with no missing values.
#
#
# ---

# %% [markdown]
# # Correct data format
# The last step in data cleaning is checking and making sure that all data is in the correct format (int, float, text or other).
#
# In Pandas, use:
#
# .dtype() to check the data type
#
# .astype() to change the data type

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# Some columns in the dataset are not of the correct data type. For example, numerical variables like "bore" and "stroke", which describe aspects of the car engine, are expected to be of type float or int. However, they appear as type object.
#
# It's important to convert data types to match the nature of each column, and this can be done using the astype() method.

# %%
df[['bore','stroke']] = df[['bore','stroke']].astype('float')
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
# list the columns after the conversion
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# Result: cleansed data set with no missing values and with all data in its proper format.
#
#
# ---

# %% [markdown]
# # Data Standardization
# Standardization is the process of transforming data into a common format, allowing the researcher to make the meaningful comparison.

# %% [markdown]
# In the current dataset, the fuel consumption in the columns "city-mpg" and "highway-mpg" is expressed in mpg (miles per gallon). Since the application being developed targets a country that uses the liters per 100 kilometers (L/100km) standard, it was necessary to transform the data accordingly.
#
# The values were converted from mpg to L/100km using the formula:
#
# L/100km = 235 / mpg
#
# This transformation allows for fuel consumption to be interpreted in a format aligned with international standards, particularly in countries that use the metric system, making it easier to compare vehicle performance.

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# Convert mpg to L/100km by mathematical operation (235 divided by mpg)
df['city-mpg'] = 235/df['city-mpg']
# rename column name from "city-mpg" to "city-L/100km"
df.rename(columns={'city-mpg':'city-L/100km'},inplace=True)
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df["highway-mpg"] = 235 / df["highway-mpg"]

df.rename(columns={'highway-mpg':'highway-L/100km'}, inplace=True)

df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ---
#
# # Data Normalization
#
# Normalization is the process of transforming values of several variables into a similar range.

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-L/100km',
#        'highway-L/100km', 'price'],
#       dtype='object')

# %% [markdown]
# When working with variables such as "length", "width", and "height", it can be helpful to bring their values to a common scale to simplify comparison and analysis. In this case, normalization is applied so that the values of each variable range from 0 to 1.
#
# This is done by dividing each value in the column by the maximum value of that same column, following the formula:
#
# normalized_value = (original value) / (maximum value)
#
# As a result, the largest value becomes 1, and all other values fall proportionally between 0 and 1.

# %%
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()
df['height'] = df['height']/df['height'].max()
print(df[['length','width','height']])
# Out:
#        length     width    height
# 0    0.811148  0.890278  0.816054
# 1    0.822681  0.909722  0.876254
# 2    0.848630  0.919444  0.908027
# 3    0.848630  0.922222  0.908027
# 4    0.851994  0.920833  0.887960
# ..        ...       ...       ...
# 195  0.907256  0.956944  0.928094
# 196  0.907256  0.955556  0.928094
# 197  0.907256  0.956944  0.928094
# 198  0.907256  0.956944  0.928094
# 199  0.907256  0.956944  0.928094
#
# [200 rows x 3 columns]

# %% [markdown]
# ---
# # Binning
# Binning is a process of transforming continuous numerical variables into discrete categorical 'bins' for grouped analysis.

# %%
# horsepower column
df['horsepower'] = df['horsepower'].astype('float')
print(df['horsepower'].min())
print(df['horsepower'].max())
print(df['horsepower'].nunique())
# Out:
# 48.0
# 262.0
# 59

# %% [markdown]
# In the dataset, the "horsepower" column contains real numerical values ranging from 48 to 262, with 59 unique values in total. However, when the goal is to compare car prices based on general horsepower categories rather than precise numbers, it becomes more practical to group the values into broader categories.
#
# To simplify the analysis, the horsepower values can be divided into three distinct bins, representing low, medium, and high horsepower ranges. This transformation allows for a clearer understanding of trends or differences in price across general horsepower levels, instead of analyzing every specific value.
#
# The cut function from the Pandas library can be used to perform this segmentation, turning continuous numerical data into categorical bins.

# %%
# Plot the histogram of horsepower to see the distribution of horsepower
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df['horsepower'])

plt.pyplot.xlabel('horsepower')
plt.pyplot.ylabel('count')
plt.pyplot.title('horsepower bins')
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# To create three bins of equal width from the "horsepower" column, the `numpy.linspace()` function can be used. The starting point is set to the minimum value of the "horsepower" column, and the ending point is set to its maximum value. Since the goal is to divide the range into three equal parts, four evenly spaced numbers are needed to represent the bin edges. These four values define the boundaries of the three bins.

# %%
bins = np.linspace(min(df['horsepower']), max(df['horsepower']),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
# set group names
group_names = ['Low','Medium','High']

# %% [markdown]
# Apply the function `'cut'` to determine what each value of df['horsepower'] belongs to.

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'],bins,labels=group_names,include_lowest=True)
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0        111.0               Low
# 1        154.0            Medium
# 2        102.0               Low
# 3        115.0               Low
# 4        110.0               Low
# 5        110.0               Low
# 6        110.0               Low
# 7        140.0            Medium
# 8        101.0               Low
# 9        101.0               Low
# 10       121.0            Medium
# 11       121.0            Medium
# 12       121.0            Medium
# 13       182.0            Medium
# 14       182.0            Medium
# 15       182.0            Medium
# 16        48.0               Low
# 17        70.0               Low
# 18        70.0               Low
# 19        68.0               Low

# %% [markdown]
# See the number of vehicles in each bin:

# %%
df['horsepower-binned'].value_counts()
# Out:
# horsepower-binned
# Low       152
# Medium     43
# High        5
# Name: count, dtype: int64

# %% [markdown]
# Plot the distribution of each bin:

# %%
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# I successfully reduced the 59 unique horsepower values into just 3 intervals.

# %% [markdown]
# ---
#
# # Turning Categorical Variables into Quantitative Variables
# # Indicator Variable
#
# What is an indicator variable?
#
# An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning.
#
# Why use indicator variables?
#
# Indicator variables are used to convert categorical variables into a numeric form, enabling their use in regression analysis in later modules.
#
# Example
#
# The column "fuel-type" has two unique values: "gas" or "diesel". Regression doesn't understand words, only numbers. To use this attribute in regression analysis, i can convert "fuel-type" to indicator variables.
#
# Use the Panda method `'get_dummies'` to assign numerical values to different categories of fuel type.

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-L/100km',
#        'highway-L/100km', 'price', 'horsepower-binned'],
#       dtype='object')

# %%
dummy_variable_1 = pd.get_dummies(df['fuel-type'])
dummy_variable_1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True

# %% [markdown]
# In the data frame, column 'fuel-type' now has values for 'gas' and 'diesel' as 0s and 1s.

# %% [markdown]
# merge data frame 'df' and 'dummy_variable_1'

# %%
df = pd.concat([df,dummy_variable_1],axis=1)

# %% [markdown]
# drop original column 'fuel-type' from 'df'

# %%
df.drop('fuel-type',axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          1                122  alfa-romero        std          two
# 2          2                164         audi        std         four
# 3          2                164         audi        std         four
# 4          2                122         audi        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1    hatchback          rwd           front        94.5  0.822681  ...
# 2        sedan          fwd           front        99.8  0.848630  ...
# 3        sedan          4wd           front        99.4  0.848630  ...
# 4        sedan          fwd           front        99.8  0.851994  ...
#
#    stroke  compression-ratio  horsepower peak-rpm city-L/100km  \
# ...

# %% [markdown]
# Similar to before, create an indicator variable for the column "aspiration"

# %%
dummy_variable_2 = pd.get_dummies(df['aspiration'])
dummy_variable_2.head()
# Out:
#     std  turbo
# 0  True  False
# 1  True  False
# 2  True  False
# 3  True  False
# 4  True  False

# %%
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)

# %%
dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0            True             False
# 1            True             False
# 2            True             False
# 3            True             False
# 4            True             False

# %% [markdown]
# Merge the new dataframe to the original dataframe, then drop the column 'aspiration'.

# %%
df = pd.concat([df,dummy_variable_2],axis=1)

# %%
df.drop(['aspiration'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          1                122  alfa-romero          two    hatchback
# 2          2                164         audi         four        sedan
# 3          2                164         audi         four        sedan
# 4          2                122         audi          two        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  \
# 0          rwd           front        88.6  0.811148  0.890278  ...
# 1          rwd           front        94.5  0.822681  0.909722  ...
# 2          fwd           front        99.8  0.848630  0.919444  ...
# 3          4wd           front        99.4  0.848630  0.922222  ...
# 4          fwd           front        99.8  0.851994  0.920833  ...
#
#    horsepower  peak-rpm city-L/100km highway-L/100km    price  \
# 0       111.0    5000.0    11.190476        8.703704  16500.0
# ...

# %% [markdown]
# # Save the new csv:

# %%
df.to_csv('clean_df.csv')
