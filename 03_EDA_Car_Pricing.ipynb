# %% [markdown]
# # What are the main characteristics that have the most impact on the car price?

# %% [markdown]
# Import libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# filepath='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

# %%
df = pd.read_csv('automobileEDA.csv')
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# # Analyzing Individual Feature Patterns Using Visualization

# %% [markdown]
# How to choose the right visualization method?
#
# When visualizing individual variables, it is important to first understand what type of variable i am dealing with. This will help to find the right visualization method for that variable.

# %%
# list the data types for each column
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# What is the data type of the column "peak-rpm"?

# %%
df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
#  calculate the correlation between variables of type "int64" or "float64" using the method "corr":

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['int64','float64'])
numeric_df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# - Close to +1 → strong positive correlation
#
# - Close to -1 → strong negative correlation
#
# - Close to 0 → no correlation

# %% [markdown]
# Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.

# %%
df[['bore','compression-ratio','horsepower']].corr()
# Out:
#                        bore  compression-ratio  horsepower
# bore               1.000000           0.001263    0.566936
# compression-ratio  0.001263           1.000000   -0.214514
# horsepower         0.566936          -0.214514    1.000000

# %% [markdown]
# ---
#
# # Continuous Numerical Variables:
#
# Continuous numerical variables are numbers that can take any value.
#
# regplot() helps visualize the linear relationship between a variable and price.
#
# It plots both the data points and a regression line.
#
# This is useful for understanding which variables may help predict the price.
#
#
# ---
#
#
# see several examples of different linear relationships:

# %% [markdown]
# # Positive Linear Relationship

# %% [markdown]
# scatterplot of 'engine-size' and 'price'

# %%
sns.regplot(x='engine-size',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 53228.17309969514)

# %% [markdown]
# As the engine-size goes up, the price goes up: this indicates a positive direct correlation between these two variables. Engine size seems like a pretty good predictor of price since the regression line is almost a perfect diagonal line.

# %% [markdown]
# i can examine the correlation between 'engine-size' and 'price' and see that it's approximately 0.87.

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# Highway mpg is a potential predictor variable of price. to find the scatterplot of "highway-mpg" and "price":

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 48169.7646478687)

# %% [markdown]
# As highway-mpg goes up, the price goes down: this indicates an inverse/negative relationship between these two variables. Highway mpg could potentially be a predictor of price.

# %% [markdown]
# i can examine the correlation between 'highway-mpg' and 'price' and see it's approximately -0.704.

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# ---
# # Weak Linear Relationship
#
# Let's see if "peak-rpm" is a predictor variable of "price".

# %%
sns.regplot(x='peak-rpm',y='price',data=df)
plt.ylim=(0,)

# %% [markdown]
# Peak rpm does not seem like a good predictor of the price at all since the regression line is close to horizontal. Also, the data points are very scattered and far from the fitted line, showing lots of variability. Therefore, it's not a reliable variable.

# %% [markdown]
# We can examine the correlation between 'peak-rpm' and 'price' and see it's approximately -0.101616.

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# ---
#
#
# Find the correlation between x="stroke" and y="price".
#
# peak-rpm and price 0.0823 very weak correlation (almost no relationship)

# %%
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke',y='price',data=df)
plt.ylim=(0,)

# %% [markdown]
# There is a weak correlation between the variable 'stroke' and 'price.' as such regression will not work well. i can see this using "regplot" to demonstrate this.
#
#
# ---

# %% [markdown]
# # Categorical Variables
#
# These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.

# %% [markdown]
#  the relationship between "body-style" and "price".

# %%
sns.boxplot(x='body-style',y='price',data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %% [markdown]
# We see that the distributions of price between the different body-style categories have a significant overlap, so body-style would not be a good predictor of price.

# %% [markdown]
# examine engine "engine-location" and "price":

# %%
sns.boxplot(x='engine-location',y='price',data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %% [markdown]
# Here i see that the distribution of price between these two engine-location categories, front and rear, are distinct enough to take engine-location as a potential good predictor of price.

# %% [markdown]
# examine "drive-wheels" and "price".

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# Here i see that the distribution of price between the different drive-wheels categories differs. As such, drive-wheels could potentially be a predictor of price.
#
# ---

# %% [markdown]
# # Descriptive Statistical Analysis
#
# The `describe function` automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.
#
# This will show:
#
# the count of that variable
#
# the mean
#
# the standard deviation (std)
#
# the minimum value
#
# the IQR (Interquartile Range: 25%, 50% and 75%)
#
# the maximum value

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %% [markdown]
# The default setting of "describe" skips variables of type object. i can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# `Value Counts`
# The value_counts() method in Pandas is a great way to understand how many instances exist for each category within a variable. For example, applying it to the 'drive-wheels' column will show the number of cars that fall under each drive type (e.g., front-wheel, rear-wheel, four-wheel drive).
#
# Important Note:
#
# value_counts() only works on a Pandas Series, not a DataFrame.
# Therefore, i must use single brackets when selecting the column:
#
#  df['drive-wheels'] → Correct (returns a Series)
#
#  df[['drive-wheels']] → Incorrect in this case (returns a DataFrame)

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %%
type(df['drive-wheels'].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# i can convert the series to a dataframe as follows:

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
type(df['drive-wheels'].value_counts().to_frame())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# repeat the above steps but save the results to the dataframe "drive_wheels_counts" and rename the column 'drive-wheels' to 'value_counts'.

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.reset_index(inplace=True)
drive_wheels_counts = drive_wheels_counts.rename(columns={'drive-wheels':'value_counts'})
drive_wheels_counts
# Out:
#   value_counts  count
# 0          fwd    118
# 1          rwd     75
# 2          4wd      8

# %% [markdown]
# rename the index to 'drive-wheels'

# %%
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#              value_counts  count
# drive-wheels
# 0                     fwd    118
# 1                     rwd     75
# 2                     4wd      8

# %% [markdown]
# repeat the above process for the variable 'engine-location'.

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location':'value_counts'},inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %% [markdown]
# After examining the value counts of the engine location, i see that engine location would not be a good predictor variable for the price. This is because i only have three cars with a rear engine and 198 with an engine in the front, so this result is skewed. Thus, i am not able to draw any conclusions about the engine location.
#
# ---

# %% [markdown]
# # Basics of Grouping
# The "groupby" method groups data by different categories. The data is grouped based on one or several variables, and analysis is performed on the individual groups.
#
# For example, let's group by the variable "drive-wheels". i see that there are 3 different categories of drive wheels

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# If we want to know, on average, which type of drive wheel is most valuable, i can group "drive-wheels" and then average them.
#
# i can select the columns 'drive-wheels', 'body-style' and 'price', then assign it to the variable "df_group_one".

# %%
df_group_one = df[['drive-wheels','body-style','price']]

# %% [markdown]
# i can then calculate the average price for each of the different categories of data.

# %%
df_grouped = df_group_one.groupby(['drive-wheels'], as_index=False).agg({'price':'mean'})
df_grouped
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# i grouped the data by drive type and calculated the average price for each category. Rear-wheel drive vehicles were the most expensive, followed by all-wheel drive, and then front-wheel drive was the cheapest.

# %% [markdown]
# i can also group by multiple variables. For example, group by both 'drive-wheels' and 'body-style'. This groups the dataframe by the unique combination of 'drive-wheels' and 'body-style'.store the results in the variable 'grouped_test1'.

# %%
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# The highest average price is for cars with:
#
# Rear-wheel drive (RWD)
#
# Hardtop or convertible body style
#
# The cheapest trims are:
#
# Front-wheel drive (FWD)
#
# Hatchback or hardtop body style
#
#
# ---

# %% [markdown]
#  A pivot table
#
# i can convert the dataframe to a pivot table using the method "pivot" to create a pivot table from the groups.
#
# In this case, i will leave the drive-wheels variable as the rows of the table, and pivot body-style to become the columns of the table:

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# often, i will not have data for some of the pivot cells. i can fill these missing cells with the value 0, but any other value could potentially be used as well.

# %%
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# ---
#
# Use the "groupby" function to find the average "price" of each car based on "body-style".

# %%
df_gptest2 = df[['body-style','price']]
grouped_test2 = df_gptest2.groupby(['body-style'],as_index=False).mean()
grouped_test2
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %% [markdown]
# ---

# %% [markdown]
# Variables: Drive Wheels and Body Style vs. Price
#
# use a heat map to visualize the relationship between Body Style vs Price.

# %%
# use the grouped result
plt.pcolor(grouped_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %% [markdown]
# The heatmap plots price using colors.
#
# The vertical axis represents drive-wheels, and the horizontal axis represents body-style.
#
# This allows us to visually see the relationship between price and both 'drive-wheel' and 'body-style'.
#
# **Problem:**
#
# "The default labels convey no useful information. to change that:"

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

# label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

# move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

# insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

# rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# ---
#
#
# The main question i want to answer in this module is, "What are the main characteristics which have the most impact on the car price?".
#
# To get a better measure of the important characteristics, i look at the `correlation` of these variables with the car price. In other words: how is the car price dependent on this variable?
#
# # Correlation and Causation
#
# * Correlation: a measure of the extent of interdependence between variables.
#
# * Causation: the relationship between cause and effect between two variables.

# %% [markdown]
# **Pearson Correlation**
#
# The Pearson Correlation measures the linear dependence between two variables X and Y.
#
# The resulting coefficient is a value between -1 and 1 inclusive, where:
#
# * 1: Perfect positive linear correlation.
#
# * 0: No linear correlation, the two variables most likely do not affect each other.
#
# * -1: Perfect negative linear correlation.

# %% [markdown]
# Pearson Correlation is the default method of the function "corr". i can calculate the Pearson Correlation of the of the 'int64' or 'float64' variables.

# %%
df.select_dtypes(include=['int64','float64']).corr()
#or df.select_dtypes(include=['number']).corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# **P-value**
#
# The P-value is the probability value that the correlation between these two variables is statistically significant.

# %% [markdown]
# | P-value      | Interpretation                                                                   |
# | ------------ | -------------------------------------------------------------------------------- |
# | `p <= 0.001` | 🔥 Very strong evidence of a real (statistically significant) correlation        |
# | `p <= 0.05`  | ✅ Moderate evidence of a real correlation                                        |
# | `p <= 0.1`   | ⚠️ Weak evidence – the correlation might be due to chance                        |
# | `p > 0.1`    | ❌ No evidence of a real correlation – the relationship is likely not significant |

# %% [markdown]
# i can obtain this information using "stats" module in the "scipy" library.

# %%
from scipy import stats

# %% [markdown]
# wheel-base vs. price

# %%
# calculate the Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is 0.5846418222655081, with a P-value of P = 8.076488270732947e-20

# %% [markdown]
# Since the p-value is < 0.001, the correlation between wheel-base and price is statistically significant, although the linear relationship isn't extremely strong (~0.585).
#
# ---
# Horsepower vs. Price
#
# calculate the Pearson Correlation Coefficient and P-value of 'horsepower' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is 0.809574567003656, with a P-value of P = 6.369057428259571e-48

# %% [markdown]
# Since the p-value is < 0.001, the correlation between horsepower and price is statistically significant, and the linear relationship is quite strong (~0.809, close to 1).
#
#
# ---
#
# Length vs. Price
#
# calculate the Pearson Correlation Coefficient and P-value of 'length' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['length'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is 0.690628380448364, with a P-value of P = 8.016477466158771e-30

# %% [markdown]
# Since the p-value is < 0.001, the correlation between length and price is statistically significant, and the linear relationship is moderately strong (~0.691).
#
#
# ---
# Width vs. Price
#
# calculate the Pearson Correlation Coefficient and P-value of 'width' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['width'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522674, with a P-value of P = 9.20033551048134e-38

# %% [markdown]
# Since the p-value is < 0.001, the correlation between width and price is statistically significant, and the linear relationship is quite strong (~0.751).
#
#
# ---
#
# Curb-Weight vs. Price
#
# calculate the Pearson Correlation Coefficient and P-value of 'curb-weight' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702845, with a P-value of P = 2.1895772388939584e-53

# %% [markdown]
# Since the p-value is < 0.001, the correlation between curb-weight and price is statistically significant, and the linear relationship is quite strong (~0.834).
#
#
# ---
# Engine-Size vs. Price
#
# calculate the Pearson Correlation Coefficient and P-value of 'engine-size' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185, with a P-value of P = 9.265491622198827e-64

# %% [markdown]
# Since the p-value is < 0.001, the correlation between engine-size and price is statistically significant, and the linear relationship is very strong (~0.872).
#
#
# ---
# Bore vs. Price
#
# calculate the Pearson Correlation Coefficient and P-value of 'bore' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626603, with a P-value of P = 8.049189483935246e-17

# %% [markdown]
#  p-value is
#  0.001, the correlation between bore and price is statistically significant, but the linear relationship is only moderate (~0.543).
#
#
# ---
# City-mpg vs. Price

# %%
pearson_coef, p_value = stats.pearsonr(df['city-mpg'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is -0.6865710067844679, with a P-value of P = 2.3211320655674997e-29

# %% [markdown]
# Since the p-value is < 0.001, the correlation between city-mpg and price is statistically significant, and the coefficient of about -0.687 shows that the relationship is negative and moderately strong.
#
#
# ---
# Highway-mpg vs. Price

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'],df['price'])
print(f"The Pearson Correlation Coefficient is {pearson_coef}, with a P-value of P = {p_value}")
# Out:
# The Pearson Correlation Coefficient is -0.7046922650589529, with a P-value of P = 1.749547114447669e-31

# %% [markdown]
# Since the p-value is < 0.001, the correlation between highway-mpg and price is statistically significant, and the coefficient of about -0.705 shows that the relationship is negative and moderately strong.
#
# ---

# %% [markdown]
# ## 📌 Conclusion: Important Variables for Predicting Car Price
#
# After performing exploratory data analysis (EDA), i identified the variables that are most correlated with the car price. These variables will be important inputs for building predictive models.
#
# ### ✅ Selected Continuous Numerical Variables:
# - `length`
# - `width`
# - `curb-weight`
# - `engine-size`
# - `horsepower`
# - `city-mpg`
# - `highway-mpg`
# - `wheel-base`
# - `bore`
#
# ### ✅ Selected Categorical Variable:
# - `drive-wheels`
#
# Feeding the machine learning models with these meaningful variables will enhance their ability to accurately predict car prices. Eliminating irrelevant or weakly correlated features helps in improving model performance and interpretability.
